# %%
# Reading CSV to a df - Change to spark.read.csv
url = "https://raw.githubusercontent.com/raul-arrabales/BigData-Hands-on/master/Spark/Spark3/data/GimeMeCredit.csv"
from pyspark import SparkFiles
spark.sparkContext.addFile(url)

df = spark.read.csv("file://"+SparkFiles.get("GimeMeCredit.csv"), header=True, inferSchema=True, sep=",")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- _id: integer (nullable = true)
# -- label: double (nullable = true)
# -- Revolving: double (nullable = true)
# -- age: integer (nullable = true)
# -- Num3059: integer (nullable = true)
# -- DebtRatio: double (nullable = true)
# -- MonthlyIncome: double (nullable = true)
# -- NumberOfOpenCreditLinesAndLoans: integer (nullable = true)
# -- NumberOfTimes90DaysLate: integer (nullable = true)
# -- NumLoans: integer (nullable = true)
# -- Num6089: integer (nullable = true)
# -- NumberOfDependents: integer (nullable = true)
#
# </div>

# %%
# Missing values?
df.filter(df.NumberOfTimes90DaysLate == '').count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: 0</div>

# %%
# Checking number of delinquents
df.groupBy("label").count().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+------+
# label| count|
# +-----+------+
#   0.0|111912|
#   1.0|  8357|
# +-----+------+
#
# </div>

# %%
# Register a temp table to be used with the SQL API
df.registerTempTable("traindata")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Using a selection from the Spark Dataframe as a pandas dataframe
import pandas as pd
matureDelinquents = df.filter("label = 1 and age > 50").toPandas()
matureDelinquents.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_id</th>
#       <th>label</th>
#       <th>Revolving</th>
#       <th>age</th>
#       <th>Num3059</th>
#       <th>DebtRatio</th>
#       <th>MonthlyIncome</th>
#       <th>NumberOfOpenCreditLinesAndLoans</th>
#       <th>NumberOfTimes90DaysLate</th>
#       <th>NumLoans</th>
#       <th>Num6089</th>
#       <th>NumberOfDependents</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>96226</td>
#       <td>1.0</td>
#       <td>0.974184</td>
#       <td>55</td>
#       <td>1</td>
#       <td>0.565208</td>
#       <td>4500.0</td>
#       <td>7</td>
#       <td>0</td>
#       <td>2</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>43024</td>
#       <td>1.0</td>
#       <td>0.820257</td>
#       <td>73</td>
#       <td>1</td>
#       <td>0.588343</td>
#       <td>4374.0</td>
#       <td>9</td>
#       <td>2</td>
#       <td>2</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>17205</td>
#       <td>1.0</td>
#       <td>1.000000</td>
#       <td>53</td>
#       <td>0</td>
#       <td>0.000000</td>
#       <td>2900.0</td>
#       <td>2</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>71057</td>
#       <td>1.0</td>
#       <td>0.739464</td>
#       <td>67</td>
#       <td>0</td>
#       <td>1.083739</td>
#       <td>6364.0</td>
#       <td>22</td>
#       <td>0</td>
#       <td>9</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>120425</td>
#       <td>1.0</td>
#       <td>1.001052</td>
#       <td>54</td>
#       <td>0</td>
#       <td>0.371898</td>
#       <td>5600.0</td>
#       <td>6</td>
#       <td>0</td>
#       <td>2</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.feature import IndexToString, StringIndexer, VectorAssembler
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Index labels, adding metadata to the label column.
# Fit on whole dataset to include all labels in index.
labelIndexer = StringIndexer(inputCol="label", outputCol="indexedLabel").fit(df)
labelIndexer.labels
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: [&#39;0.0&#39;, &#39;1.0&#39;]</div>

# %%
plan_indexer = StringIndexer(inputCol = 'intl_plan', outputCol = 'intl_plan_indexed')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Create the feature columns
assembler = VectorAssembler(
  inputCols = ['Revolving', 'age', 'Num3059', 'DebtRatio', 'MonthlyIncome', 'NumberOfOpenCreditLinesAndLoans', 'NumberOfTimes90DaysLate', 'NumLoans', 'Num6089', 'NumberOfDependents'],
  outputCol = 'features')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Training the model
classifier = RandomForestClassifier(labelCol = 'label', featuresCol = 'features')
pipeline = Pipeline(stages=[labelIndexer, assembler, classifier])
model = pipeline.fit(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Evaluating the model
# Need to do that over a test set, not the same training set. 
from pyspark.ml.evaluation import BinaryClassificationEvaluator
 
predictions = model.transform(df)
evaluator = BinaryClassificationEvaluator()
auroc = evaluator.evaluate(predictions, {evaluator.metricName: "areaUnderROC"})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predictions.take(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: [Row(_id=4821, label=0.0, Revolving=0.03419858, age=68, Num3059=0, DebtRatio=0.47615442, MonthlyIncome=5283.0, NumberOfOpenCreditLinesAndLoans=10, NumberOfTimes90DaysLate=0, NumLoans=2, Num6089=0, NumberOfDependents=0, indexedLabel=0.0, features=DenseVector([0.0342, 68.0, 0.0, 0.4762, 5283.0, 10.0, 0.0, 2.0, 0.0, 0.0]), rawPrediction=DenseVector([19.4285, 0.5715]), probability=DenseVector([0.9714, 0.0286]), prediction=0.0),
#  Row(_id=67553, label=0.0, Revolving=0.9999999, age=63, Num3059=0, DebtRatio=0.046051417, MonthlyIncome=5406.0, NumberOfOpenCreditLinesAndLoans=1, NumberOfTimes90DaysLate=1, NumLoans=0, Num6089=0, NumberOfDependents=0, indexedLabel=0.0, features=DenseVector([1.0, 63.0, 0.0, 0.0461, 5406.0, 1.0, 1.0, 0.0, 0.0, 0.0]), rawPrediction=DenseVector([14.5702, 5.4298]), probability=DenseVector([0.7285, 0.2715]), prediction=0.0),
#  Row(_id=53187, label=0.0, Revolving=0.87387085, age=78, Num3059=1, DebtRatio=0.19645089, MonthlyIncome=4000.0, NumberOfOpenCreditLinesAndLoans=2, NumberOfTimes90DaysLate=0, NumLoans=0, Num6089=0, NumberOfDependents=0, indexedLabel=0.0, features=DenseVector([0.8739, 78.0, 1.0, 0.1965, 4000.0, 2.0, 0.0, 0.0, 0.0, 0.0]), rawPrediction=DenseVector([18.0342, 1.9658]), probability=DenseVector([0.9017, 0.0983]), prediction=0.0)]</div>

# %%
auroc
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: 0.8350982111724856</div>

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- _id: integer (nullable = true)
# -- label: double (nullable = true)
# -- Revolving: double (nullable = true)
# -- age: integer (nullable = true)
# -- Num3059: integer (nullable = true)
# -- DebtRatio: double (nullable = true)
# -- MonthlyIncome: double (nullable = true)
# -- NumberOfOpenCreditLinesAndLoans: integer (nullable = true)
# -- NumberOfTimes90DaysLate: integer (nullable = true)
# -- NumLoans: integer (nullable = true)
# -- Num6089: integer (nullable = true)
# -- NumberOfDependents: integer (nullable = true)
#
# </div>

# %%
from pyspark.ml.tuning import ParamGridBuilder, TrainValidationSplit
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train, test = df.randomSplit([0.9, 0.1], seed=12345)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rf = RandomForestClassifier(labelCol="label", featuresCol="features")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(rf.params)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>doc</th><th>name</th><th>parent</th><th>typeConverter</th></tr></thead><tbody><tr><td>Whether bootstrap samples are used when building trees.</td><td>bootstrap</td><td>RandomForestClassifier_5f68df019994</td><td>List()</td></tr><tr><td>If false, the algorithm will pass trees to executors to match instances with nodes. If true, the algorithm will cache node IDs for each instance. Caching can speed up training of deeper trees. Users can set how often should the cache be checkpointed or disable it by setting checkpointInterval.</td><td>cacheNodeIds</td><td>RandomForestClassifier_5f68df019994</td><td>List()</td></tr><tr><td>set checkpoint interval (>= 1) or disable checkpoint (-1). E.g. 10 means that the cache will get checkpointed every 10 iterations. Note: this setting will be ignored if the checkpoint directory is not set in the SparkContext.</td><td>checkpointInterval</td><td>RandomForestClassifier_5f68df019994</td><td>List()</td></tr><tr><td>The number of features to consider for splits at each tree node. Supported options: 'auto' (choose automatically for task: If numTrees == 1, set to 'all'. If numTrees > 1 (forest), set to 'sqrt' for classification and to 'onethird' for regression), 'all' (use all features), 'onethird' (use 1/3 of the features), 'sqrt' (use sqrt(number of features)), 'log2' (use log2(number of features)), 'n' (when n is in the range (0, 1.0], use n * number of features. When n is in the range (1, number of features), use n features). default = 'auto'</td><td>featureSubsetStrategy</td><td>RandomForestClassifier_5f68df019994</td><td>List()</td></tr><tr><td>features column name.</td><td>featuresCol</td><td>RandomForestClassifier_5f68df019994</td><td>List()</td></tr><tr><td>Criterion used for information gain calculation (case-insensitive). Supported options: entropy, gini</td><td>impurity</td><td>RandomForestClassifier_5f68df019994</td><td>List()</td></tr><tr><td>label column name.</td><td>labelCol</td><td>RandomForestClassifier_5f68df019994</td><td>List()</td></tr><tr><td>Leaf indices column name. Predicted leaf index of each instance in each tree by preorder.</td><td>leafCol</td><td>RandomForestClassifier_5f68df019994</td><td>List()</td></tr><tr><td>Max number of bins for discretizing continuous features.  Must be >=2 and >= number of categories for any categorical feature.</td><td>maxBins</td><td>RandomForestClassifier_5f68df019994</td><td>List()</td></tr><tr><td>Maximum depth of the tree. (>= 0) E.g., depth 0 means 1 leaf node; depth 1 means 1 internal node + 2 leaf nodes.</td><td>maxDepth</td><td>RandomForestClassifier_5f68df019994</td><td>List()</td></tr><tr><td>Maximum memory in MB allocated to histogram aggregation. If too small, then 1 node will be split per iteration, and its aggregates may exceed this size.</td><td>maxMemoryInMB</td><td>RandomForestClassifier_5f68df019994</td><td>List()</td></tr><tr><td>Minimum information gain for a split to be considered at a tree node.</td><td>minInfoGain</td><td>RandomForestClassifier_5f68df019994</td><td>List()</td></tr><tr><td>Minimum number of instances each child must have after split. If a split causes the left or right child to have fewer than minInstancesPerNode, the split will be discarded as invalid. Should be >= 1.</td><td>minInstancesPerNode</td><td>RandomForestClassifier_5f68df019994</td><td>List()</td></tr><tr><td>Minimum fraction of the weighted sample count that each child must have after split. If a split causes the fraction of the total weight in the left or right child to be less than minWeightFractionPerNode, the split will be discarded as invalid. Should be in interval [0.0, 0.5).</td><td>minWeightFractionPerNode</td><td>RandomForestClassifier_5f68df019994</td><td>List()</td></tr><tr><td>Number of trees to train (>= 1).</td><td>numTrees</td><td>RandomForestClassifier_5f68df019994</td><td>List()</td></tr><tr><td>prediction co ...

# %%
paramGrid = ParamGridBuilder()\
    .addGrid(rf.numTrees, [10, 20, 50, 100]) \
    .addGrid(rf.maxDepth, [0, 1, 4, 8])\
    .addGrid(rf.impurity, ["entropy", "gini"])\
    .build()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
tvs = TrainValidationSplit(estimator=pipeline,
                           estimatorParamMaps=paramGrid,
                           evaluator=BinaryClassificationEvaluator(),
                           # 80% of the data will be used for training, 20% for validation.
                           trainRatio=0.8)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Run TrainValidationSplit, and choose the best set of parameters.
model = tvs.fit(train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Make predictions on test data. model is the model with combination of parameters
# that performed best.
testResults = model.transform(test)\
    .select("features", "label", "prediction")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
testResults.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[57]: 12063</div>

# %%
predictions = model.transform(test)
evaluator = BinaryClassificationEvaluator()
auroc = evaluator.evaluate(predictions, {evaluator.metricName: "areaUnderROC"})
auroc
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[60]: 0.8483195623280816</div>
